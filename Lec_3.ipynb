# %% [markdown]
# <a href="https://colab.research.google.com/github/mayooreshmoodanwal/ANTP/blob/main/Lec_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add(a,b):
  return a+b

print(add(2,3))

# %%
#lambda function
x = lambda a,b : a+b

print(x(2,3))

# %%
st = "ayush"
st1 = st.upper()
print(st1)
st2 = "AYUSH"
st3 = st2.lower()
print(st3)
st4 = "ayush kumar singh"
st5 = st4.capitalize()
print(st5)
st4 = "ayush kumar singh"
st5 = st4.title()
print(st5)
st4 = "Ayush Kumar Singh"
st5 = st4.swapcase()
print(st5)
# Out:
# AYUSH
# ayush
# Ayush kumar singh
# Ayush Kumar Singh
# aYUSH kUMAR sINGH
